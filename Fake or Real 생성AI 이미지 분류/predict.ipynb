# %% [markdown]
# ## Mount & install

# %%
# !pip install -q timm
# !pip install -q wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 25.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 64.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 20.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 kB 26.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.3 MB/s eta 0:00:00
#   Building wheel for pathtools (setup.py) ... done

# %% [markdown]
# ## 데이터 다운로드

# %%
cd /content
# Out:
# /content

# %%
import urllib
import time
import os


# 학습 데이터 다운로드 (1분 56초)

# start = time.time()
# url = 'https://share.aiconnect.kr/fake_or_real/trainFile/train.zip'
# if not os.path.exists('train.zip'):
#     urllib.request.urlretrieve(url, 'train.zip')
# print('train time : ', time.strftime('%M:%S', time.gmtime(time.time() - start)))

# 평가용 데이터 다운로드 (4ㅂ분)

start = time.time()
url = 'https://share.aiconnect.kr/fake_or_real/testFile/test.zip'
if not os.path.exists('test.zip'):
    urllib.request.urlretrieve(url, 'test.zip')
print('test time : ', time.strftime('%M:%S', time.gmtime(time.time() - start)))
# Out:
# test time :  04:52

# %% [markdown]
# ## 데이터 압축풀기

# %%
import zipfile

# zip_file_train = "train.zip"
# output_folder_train = "data/"
# start = time.time()
# # Zip 파일 열기
# with zipfile.ZipFile(zip_file_train, 'r') as zip_ref:
#     # 모든 파일 압축 해제
#     zip_ref.extractall(output_folder_train)
# print('train time : ', time.strftime('%M:%S', time.gmtime(time.time() - start)))

#------------------

zip_file_test = "test.zip"
output_folder_test = "data/"
start = time.time()
# Zip 파일 열기
with zipfile.ZipFile(zip_file_test, 'r') as zip_ref:
    # 모든 파일 압축 해제
    zip_ref.extractall(output_folder_test)
print('test time : ', time.strftime('%M:%S', time.gmtime(time.time() - start)))
# Out:
# test time :  03:00

# %% [markdown]
# ## cd 경로 이동

# %%
cd /content/drive/MyDrive/github/Fake or Real 판별/Fake_or_Real
# Out:
# /content/drive/MyDrive/github/Fake or Real 판별/Fake_or_Real

# %% [markdown]
# ## GPU 캐시 초기화

# %%
import gc
import torch

gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## Run(Train)

# %%
# !python train.py \
# --datadir /content/data/train \
# --model effnet \
# --n_epochs 1 \
# --batch_size 32
# Out:
# {'datadir': '/content/data/train', 'model': 'effnet', 'n_epochs': 1, 'batch_size': 32, 'optimizer': 'adam', 'lr': 0.0005, 'loss': 'bce', 'metric': ['accuracy', 'f1macro'], 'early_stopping_target': 'val_accuracy', 'early_stopping_patience': 10, 'early_stopping_mode': 'max', 'amp': False, 'gpu': 0, 'seed': 42, 'val_size': 0.3, 'num_workers': 1, 'shuffle': True, 'pin_memory': True, 'drop_last': True, 'debug': False, 'wandb': False, 'logging_interval': 100, 'plot': ['loss', 'accuracy', 'f1macro', 'elapsed_time'], 'elapsed_time': True}
# /content/drive/MyDrive/github/Fake or Real 판별/Fake_or_Real
# Train 0/1
# 100% 437/437 [05:26<00:00,  1.34it/s]
# Val 0/1
# 100% 187/187 [02:08<00:00,  1.45it/s]

# %% [markdown]
# ## Run(Predict)

# %%
# !python predict.py \
--datadir /content/data/test/images \
--sample_submission_path /content/data/test/sample_submission.csv \
--train_serial 20230627_140656 \
--batch_size 32
# Out:
# {'datadir': '/content/data/test/images', 'sample_submission_path': '/content/data/test/sample_submission.csv', 'train_serial': '20230627_140656', 'batch_size': 32, 'gpu': 0, 'seed': 42}
# Downloading model.safetensors: 100% 21.4M/21.4M [00:00<00:00, 202MB/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
#   0% 0/1824 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(
# 100% 1824/1824 [18:47<00:00,  1.62it/s]
# Done
